# %%
import tweepy
import pandas as pd
import nltk
import textblob
import bs4
from unidecode import unidecode
import datetime
import numpy as np

# %% [markdown]
# Gerando um dataframe com avaliações, para treinamento no futuro

# %%
import transformers
from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup

# %%
# PRE_TRAINED_MODEL_NAME = 'neuralmind/bert-large-portuguese-cased'

# tokenizer = BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)

# %%
# tokens = []
# token_ids = []
# for item in tweets_df['text']:
#     tokens_aux = tokenizer.tokenize(item)
#     tokens.append(tokens_aux)
#     token_ids_aux = tokenizer.convert_tokens_to_ids(tokens_aux)
#     token_ids.append(token_ids_aux)

#     encoding = tokenizer.encode_plus(
#     item,
#     max_length=100,
#     add_special_tokens=True, # Add '[CLS]' and '[SEP]'
#     return_token_type_ids=False,
#     pad_to_max_length=True,
#     return_attention_mask=True,
#     return_tensors='pt',  # Return PyTorch tensors
#     )

#     encoding.keys()

#     print(len(encoding['input_ids'][0]))
#     encoding['input_ids'][0]

#     print(tokenizer.convert_ids_to_tokens(encoding['input_ids'][0]))
# Out:
# 100
# ['[CLS]', 'Meu', 'cole', '##te', 'do', 'tu', '##s', '##ca', 'pode', 'estar', 'escrito', '“', 'É', 'só', 'cach', '##a', '##ça', ',', 'pin', '##ga', 'e', 'Giu', '##lia', '”', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# 100
# ...

# %%
MAX_LEN = 100
